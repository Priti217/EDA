# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/Priti217/EDA/main/adult.csv",header=None,names=["Age","workclass","fnlwgt","Education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","Capital-loss","hours-per-week","native-country","Listingofattributes"])

# %%
df.shape
# Out:
# (32561, 15)

# %%
df
# Out:
#        Age          workclass  fnlwgt    Education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  32561 non-null  int64
#  1   workclass            32561 non-null  object
#  2   fnlwgt               32561 non-null  int64
#  3   Education            32561 non-null  object
#  4   education-num        32561 non-null  int64
#  5   marital-status       32561 non-null  object
#  6   occupation           32561 non-null  object
#  7   relationship         32561 non-null  object
#  8   race                 32561 non-null  object
#  9   sex                  32561 non-null  object
#  10  capital-gain         32561 non-null  int64
#  11  Capital-loss         32561 non-null  int64
#  12  hours-per-week       32561 non-null  int64
#  13  native-country       32561 non-null  object
#  14  Listingofattributes  32561 non-null  object
# ...

# %%
df[df.duplicated()]
# Out:
#        Age          workclass  fnlwgt      Education  education-num  \
# 4881    25            Private  308144      Bachelors             13
# 5104    90            Private   52386   Some-college             10
# 9171    21            Private  250051   Some-college             10
# 11631   20            Private  107658   Some-college             10
# 13084   25            Private  195994        1st-4th              2
# 15059   21            Private  243368      Preschool              1
# 17040   46            Private  173243        HS-grad              9
# 18555   30            Private  144593        HS-grad              9
# 18698   19            Private   97261        HS-grad              9
# 21318   19            Private  138153   Some-college             10
# 21490   19            Private  146679   Some-college             10
# 21875   49            Private   31267        7th-8th              4
# 22300   25            Private  195994        1st-4th              2
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  32561 non-null  int64
#  1   workclass            32561 non-null  object
#  2   fnlwgt               32561 non-null  int64
#  3   Education            32561 non-null  object
#  4   education-num        32561 non-null  int64
#  5   marital-status       32561 non-null  object
#  6   occupation           32561 non-null  object
#  7   relationship         32561 non-null  object
#  8   race                 32561 non-null  object
#  9   sex                  32561 non-null  object
#  10  capital-gain         32561 non-null  int64
#  11  Capital-loss         32561 non-null  int64
#  12  hours-per-week       32561 non-null  int64
#  13  native-country       32561 non-null  object
#  14  Listingofattributes  32561 non-null  object
# ...

# %%
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
numeric_features
# Out:
# ['Age',
#  'fnlwgt',
#  'education-num',
#  'capital-gain',
#  'Capital-loss',
#  'hours-per-week']

# %%
categorical_features
# Out:
# ['workclass',
#  'Education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'Listingofattributes']

# %%
df["Listingofattributes"].value_counts()
# Out:
#  <=50K    24720
#  >50K      7841
# Name: Listingofattributes, dtype: int64

# %%
df["Listingofattributes"].dtype
# Out:
# dtype('O')

# %%
sns.barplot(y=df["Age"],x=df["Listingofattributes"])
# Out:
# <AxesSubplot: xlabel='Listingofattributes', ylabel='Age'>

# %%
df.head()
# Out:
#    Age          workclass  fnlwgt   Education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  Capital-loss  hours-per-week  native-country  \
# 0          2174             0              40   United-States
# ...

# %%
df["Education"].value_counts().plot.pie(y=df["Education"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='Education'>

# %%
df1=df.groupby(["Education"])["education-num"].sum().sort_values(ascending=False).reset_index()

# %%
df1
# Out:
#         Education  education-num
# 0         HS-grad          94509
# 1    Some-college          72910
# 2       Bachelors          69615
# 3         Masters          24122
# 4       Assoc-voc          15202
# 5      Assoc-acdm          12804
# 6     Prof-school           8640
# 7            11th           8225
# 8       Doctorate           6608
# 9            10th           5598
# 10           12th           3464
# 11        7th-8th           2584
# 12            9th           2570
# 13        5th-6th            999
# 14        1st-4th            336
# 15      Preschool             51

# %%
sns.barplot(x="education-num",y="Education",data=df1)
# Out:
# <AxesSubplot: xlabel='education-num', ylabel='Education'>

# %%
df2=df.groupby(["workclass"])["hours-per-week"].sum().sort_values(ascending=True).reset_index()

# %%
df2
# Out:
#            workclass  hours-per-week
# 0       Never-worked             199
# 1        Without-pay             458
# 2        Federal-gov           39724
# 3          State-gov           50663
# 4       Self-emp-inc           54481
# 5                  ?           58604
# 6          Local-gov           85777
# 7   Self-emp-not-inc          112876
# 8            Private          913902

# %%
df2=df2.drop(df2.index[5])

# %%
df2
# Out:
#            workclass  hours-per-week
# 0       Never-worked             199
# 1        Without-pay             458
# 2        Federal-gov           39724
# 3          State-gov           50663
# 4       Self-emp-inc           54481
# 6          Local-gov           85777
# 7   Self-emp-not-inc          112876
# 8            Private          913902

# %%
plt.figure(figsize=(13,11))
sns.barplot(x=df2["workclass"],y=df2["hours-per-week"],data=df2)
# Out:
# <AxesSubplot: xlabel='workclass', ylabel='hours-per-week'>

# %%
df["occupation"].value_counts().plot.pie(y=df["occupation"],figsize=(15,15),autopct='%1.1f%%')
# Out:
# <AxesSubplot: ylabel='occupation'>

# %%
sns.barplot(x=df["Age"],y=df["occupation"],data=df2)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='occupation'>
